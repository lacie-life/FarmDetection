# %% [markdown]
# ## Purpose
# This notebook aims to load a shapefile with field polygons from Grand View, Idaho that also includes irrigation type data, and use it to test some workflow steps for feature engineering on the route to building an irrigation classifiation model.
#
# Note: this notebook runs using a conda environment called `ml_env` on the TFT shared MacBook. Export and recreate that environment for seamless reproduction.

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib

# %% [markdown]
# ### Load the data and take a quick look

# %%
gv = gpd.read_file("data/grand_view_training/grand_view_2019_training.shp")
gv.plot(figsize=(5,5), edgecolor="purple", facecolor="None")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Load satellite datasets with GEE
# Note: this page is helpful for this step if you encounter problems: https://developers.google.com/earth-engine/guides/python_install-conda#mac_5
#
# I installed the EE API in my conda env named `ml_env` instead of creating a separate one named `ee` as the guide instructs. Make sure the API installation is done when your conda env is activated, then launch Jupyter Notebook from within that conda env and the following lines should run fine.

# %%
import ee
import sys
print(sys.path)

# Trigger the authentication flow.
#ee.Authenticate()

# Initialize the library.
#ee.Initialize()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-040fd464049f> in <module>
# ----> 1 import ee
#       2 import sys
#       3 print(sys.path)
#       4
#       5 # Trigger the authentication flow.
#
# ModuleNotFoundError: No module named 'ee'
